# %%
import pandas as pd
import numpy as np
import os
import string
from fuzzywuzzy import fuzz, process
import sklearn
import matplotlib.pyplot as plt

from spellchecker import SpellChecker

from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# /Users/kchua/anaconda3/lib/python3.11/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # Cleaning Data

# %%
central_data = pd.read_csv('/Users/kchua/Documents/Data_Stories/2023-10-tx-produced-water-spills/data/central_cleaned.csv')
central_data.head()
# Out:
#   dist district_edit date_called_in date_called_in_edit date_of_spill  \
# 0   04             4     2013-01-13          2013-01-13    2013-01-13
# 1   06             6     2013-01-06          2013-01-06    2013-01-05
# 2   7C            7C     2013-01-22          2013-01-22    2013-01-22
# 3   7C            7C     2013-01-14          2013-01-14    2013-01-13
# 4   7C            7C     2013-01-14          2013-01-14    2013-01-05
#
#   date_of_spill_edit spill_number rrc_job_number  \
# 0         2013-01-13      04-1238       2013-381
# 1         2013-01-05         1291    2013-06-195
# 2         2013-01-22         1829            324
# 3         2013-01-13         1830            191
# 4         2013-01-05         1832            192
#
#                          operator_rp  \
# 0             Headington Oil Company
# 1  Quantum Resources Management, LLC
# 2                      EOG Resources
# 3      Pioneer Natural Res. USA Inc.
# 4           Molopo Energy Texas, LLC
#
#                                        operator_edit  ...  \
# 0                                     HEADINGTON OIL  ...
# 1                                  QUANTUM RESOURCES  ...
# 2                                      EOG Resources  ...
# 3  Pioneer Natural Resources (acq. by ExxonMobil ...  ...
# 4                           MOLOPO ENERGY TEXAS, LLC  ...
#
#   cleanup_oversight_austin            status  \
# 0                      NaN  assessment phase
# 1                    41284                JH
# 2                       No  assessment phase
# 3                       No     cleanup phase
# 4                       No     cleanup phase
#
#                                             comments compliance_date  \
# 0                          Leak in gathering line DS             NaN
# 1                                                NaN             NaN
# 2                                Dump valve misfired             NaN
# 3  water leg plugged up water went in oil tank, r...             NaN
# 4  heater treater was not started ran prod tank over             NaN
#
#                                                 file       sheet  \
# 0  logs/master/pattern1/All Dist Spill Log - FY 2...  January 13
# 1  logs/master/pattern1/All Dist Spill Log - FY 2...  January 13
# 2  logs/master/pattern1/All Dist Spill Log - FY 2...  January 13
# 3  logs/master/pattern1/All Dist Spill Log - FY 2...  January 13
# 4  logs/master/pattern1/All Dist Spill Log - FY 2...  January 13
#
#   cleanup_criteria cleanup_oversight rrc_job_number_2  my_of_spill
# 0              NaN               NaN              NaN   2013-01-01
# 1              NaN               NaN              NaN   2013-01-01
# 2              NaN               NaN              NaN   2013-01-01
# 3              NaN               NaN              NaN   2013-01-01
# 4              NaN               NaN              NaN   2013-01-01
#
# [5 rows x 56 columns]

# %%
data = central_data.copy(deep=True)
print(data.shape)
data.head()
# Out:
# (10326, 56)
#   dist district_edit date_called_in date_called_in_edit date_of_spill  \
# 0   04             4     2013-01-13          2013-01-13    2013-01-13
# 1   06             6     2013-01-06          2013-01-06    2013-01-05
# 2   7C            7C     2013-01-22          2013-01-22    2013-01-22
# 3   7C            7C     2013-01-14          2013-01-14    2013-01-13
# 4   7C            7C     2013-01-14          2013-01-14    2013-01-05
#
#   date_of_spill_edit spill_number rrc_job_number  \
# 0         2013-01-13      04-1238       2013-381
# 1         2013-01-05         1291    2013-06-195
# 2         2013-01-22         1829            324
# 3         2013-01-13         1830            191
# 4         2013-01-05         1832            192
#
#                          operator_rp  \
# 0             Headington Oil Company
# 1  Quantum Resources Management, LLC
# 2                      EOG Resources
# 3      Pioneer Natural Res. USA Inc.
# 4           Molopo Energy Texas, LLC
#
#                                        operator_edit  ...  \
# 0                                     HEADINGTON OIL  ...
# 1                                  QUANTUM RESOURCES  ...
# 2                                      EOG Resources  ...
# 3  Pioneer Natural Resources (acq. by ExxonMobil ...  ...
# 4                           MOLOPO ENERGY TEXAS, LLC  ...
#
#   cleanup_oversight_austin            status  \
# 0                      NaN  assessment phase
# 1                    41284                JH
# 2                       No  assessment phase
# 3                       No     cleanup phase
# 4                       No     cleanup phase
#
#                                             comments compliance_date  \
# 0                          Leak in gathering line DS             NaN
# 1                                                NaN             NaN
# 2                                Dump valve misfired             NaN
# 3  water leg plugged up water went in oil tank, r...             NaN
# 4  heater treater was not started ran prod tank over             NaN
#
#                                                 file       sheet  \
# 0  logs/master/pattern1/All Dist Spill Log - FY 2...  January 13
# 1  logs/master/pattern1/All Dist Spill Log - FY 2...  January 13
# 2  logs/master/pattern1/All Dist Spill Log - FY 2...  January 13
# 3  logs/master/pattern1/All Dist Spill Log - FY 2...  January 13
# 4  logs/master/pattern1/All Dist Spill Log - FY 2...  January 13
#
#   cleanup_criteria cleanup_oversight rrc_job_number_2  my_of_spill
# 0              NaN               NaN              NaN   2013-01-01
# 1              NaN               NaN              NaN   2013-01-01
# 2              NaN               NaN              NaN   2013-01-01
# 3              NaN               NaN              NaN   2013-01-01
# 4              NaN               NaN              NaN   2013-01-01
#
# [5 rows x 56 columns]

# %% [markdown]
# ## Functions

# %%
# Cleaning and fuzzy matching the source values

# Remove punctuation and whitespace
def remove_punctuation(text):
    text = ''.join([char for char in text if char not in string.punctuation])
    return text

def remove_whitespace(text):
    text = ' '.join(text.split())
    return text

# Spell checking
spell = SpellChecker()

def correct_spelling(x, speller=spell):
    words = spell.split_words(x)
    word_list = [spell.correction(word) if not word.isupper() else word for word in words]
    return " ".join(word_list)

# Lowercasing
def impute_nulls(col): 
    clean_col = col.fillna('null')
    clean_col = clean_col.replace('', 'null')
    clean_col = clean_col.apply(lambda x: x.strip())
    clean_col = clean_col.apply(remove_whitespace)
    return clean_col

# Functions for typo correction
def correct_typos(x, typo_dict): 
    if x in typo_dict: 
        return typo_dict[x]
    else: 
        return x

# %%
correct_spelling('SWD')
# Out:
# 'SWD'

# %%
# Functions for typo exploration

def find_best_match(value, choices, threshold=80):
    match, score = process.extractOne(value, choices)
    return match if score >= threshold else value

def plot_kcluster_elbow(word_list):
    # Create the TF-IDF vectorizer
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(word_list)

    # Experiment with a range of clusters
    max_clusters = 10
    distortions = []

    for i in range(1, max_clusters + 1):
        kmeans = KMeans(n_clusters=i, random_state=42)
        kmeans.fit(X)
        distortions.append(kmeans.inertia_)

    # Plot the Elbow curve
    plt.plot(range(1, max_clusters + 1), distortions, marker='o')
    plt.title('Elbow Method for Optimal k')
    plt.xlabel('Number of Clusters')
    plt.ylabel('Distortion')
    plt.show()

def show_kclusters(word_list, optimal_clusters):
    # Create the TF-IDF vectorizer
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(word_list)

    kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
    kmeans.fit(X)

    word_list_clusters = list(zip(word_list, kmeans.labels_))

    for cluster_id in range(optimal_clusters):
        cluster_words = [word for word, label in word_list_clusters if label == cluster_id]
        print(f"Cluster {cluster_id + 1}: {cluster_words}")
        print()
        print()

# %% [markdown]
# ## Column Record

# %%
# Reason-related columns
reason_cols = [
'type_operation',
'source', 
'probable_cause_edit',
'comments',
]

# RRC columns
rrc_cols = [
'rrc_job_number', 
'rrc_id_number',
'rrc_job_number_2'
]

# Location-related columns
loc_cols = [
'district_edit', 
'operator_edit',
    
'lease_facility_name',
'county_edit', 
'affected_area', 
'spill_on_water_edit'
]

# Whistleblower/reporting/regulations-specific columns 
rep_cols = [
'date_called_in_edit',
'date_of_spill_edit',
'spill_number', 
'rrc_job_number',
'basis', 
'affected_area', 
'swr_20', 
'swr_98exempt',
'cleanup_criteria', 
'cleanup_criteria_swr_91', 
'cleanup_criteria_7_00_doc', 
'cleanup_criteria_case_specific', 
'form_h_8rqrd_edit',
'date_h_8rcvd', 
'cleanup_oversight', 
'cleanup_oversight_district', 
'cleanup_oversight_austin', 
'status', 
'compliance_date'
]

# %% [markdown]
# ## Cleaning reason_cols - 2/4

# %%
# EDA of the nullage
complete_log = [1, 1, 1, 1]
for col, complete in zip(reason_cols, complete_log): 
    print(col)
    print('sum of nulls:', data[col].isnull().sum())
    print('coverage:', ((len(data)-data[col].isnull().sum())/ len(data)) * 100)
    print('unique values:', data[col].nunique())
    if complete == 1: 
        print('!!! COMPLETE !!!')
    print()
# Out:
# type_operation
# sum of nulls: 49
# coverage: 99.52546968816578
# unique values: 74
# !!! COMPLETE !!!
#
# source
# sum of nulls: 59
# coverage: 99.42862676738329
# unique values: 255
# !!! COMPLETE !!!
#
# probable_cause_edit
# sum of nulls: 108
# coverage: 98.9540964555491
# unique values: 249
# !!! COMPLETE !!!
#
# comments
# sum of nulls: 1023
# coverage: 90.09296920395118
# unique values: 6875
# !!! COMPLETE !!!

# %%
# DONE
col_name = 'type_operation'

# Manual values for type_operation
typo_corrections = {
    'inj/disposal': 'injection/disposal'
}

target_labels = [
    'transportation', 
    'injection/disposal', 
    'disposal',
    'injection',
    'transportation/disposal',
    'production',
    'gathering',
    'completion', 
    # plant for plant, gas plant ? 
    # tank for tank farm, tank battery ?
    # salt water station, brine facility ?
]

col_threshold = 75

# Cleaning process
new_col_name = col_name + '_clean'

data[new_col_name] = data[col_name].astype(str)
data[new_col_name] = impute_nulls(data[new_col_name]).apply(lambda x: x.lower())
data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))

# Check discrepancies
discrepancies = data[[col_name, new_col_name]]
discrepancies = discrepancies[discrepancies[col_name] != discrepancies[new_col_name]]
discrepancies.drop_duplicates()
# Out:
#               type_operation   type_operation_clean
# 120                      NaN                    nan
# 128               Production             production
# 129                    Other                  other
# 339                      SWD                    swd
# 609               Completion             completion
# 620                 Disposal               disposal
# 864                 Pipeline               pipeline
# 1084                Drilling               drilling
# 1182                   Plant                  plant
# 1578                DISPOSAL               disposal
# 1977                Fracking               fracking
# 1978                Trucking               trucking
# 1979                Plugging               plugging
# 1992             Completions            completions
# 2125               Gathering              gathering
# 2208               Transport              transport
# 2209                  Orphan                 orphan
# 2378               Gas Plant              gas plant
# 2603          Gathering Line         gathering line
# 2617                 SW LINE                sw line
# 2725       Disposal facility      disposal facility
# 3137              Processing             processing
# 3690              PRODUCTION             production
# 3691                 PIGGING                pigging
# 3694                PIPELINE               pipeline
# 3696               ABANDONED              abandoned
# 3806            INJ/DISPOSAL     injection/disposal
# 3975               RECTIFIER              rectifier
# 4069            WATER HAULER           water hauler
# 4184               TRANSPORT              transport
# 4312      INJECTION/DISPOSAL     injection/disposal
# 4567               GATHERING              gathering
# 4753          Transportation         transportation
# 4849              PROCESSING             processing
# 5001                DRILLING               drilling
# 5269          TRANSPORTATION         transportation
# 5346               COMMINGLE              commingle
# 5556     Processing Facility    processing facility
# 6018                INJ/DISP               inj/disp
# 6026            TANK BATTERY           tank battery
# 6240   Disposal (P&A'd well)  disposal (p&a'd well)
# 6298                     DCP                    dcp
# 6383     INJECTION/ DISPOSAL    injection/ disposal
# 6448             COMPLETIONS            completions
# 6526                     CPF                    cpf
# 7154           Trasportation          trasportation
# 7155          INJECTION WELL         injection well
# 7173              PRODUCTIOM             productiom
# 7175               INJECTION              injection
# 7299               Tank Farm              tank farm
# 7309      Injection/Disposal     injection/disposal
# 8162     Commercial Disposal    commercial disposal
# 9762                Transfer               transfer
# 9900       Saltwater Station      saltwater station
# 9932      Disposal/injection     disposal/injection
# 9964          Brine Facility         brine facility
# 10255          Transporation          transporation

# %%
data['type_operation_clean'].value_counts()
# Out:
# type_operation_clean
# production                       7333
# injection/disposal               2122
# commercial disposal               205
# transportation                    196
# other                             106
# drilling                           79
# nan                                49
# injection                          39
# processing                         35
# tank farm                          35
# transport                          35
# disposal                           18
# pipeline                           10
# gathering                           9
# swd                                 5
# processing facility                 3
# fracking                            3
# completions                         2
# injection/ disposal                 2
# tank battery                        2
# plant                               2
# commingle                           2
# gas plant                           2
# gathering line                      2
# storage                             2
# saltwater station                   2
# brine facility                      2
# disposal (p&a'd well)               1
# dcp                                 1
# disposal/injection                  1
# cpf                                 1
# trasportation                       1
# productiom                          1
# transfer                            1
# inj/disp                            1
# injection well                      1
# sw line                             1
# transportation/disposal             1
# waste collection and skimming       1
# water hauler                        1
# rectifier                           1
# abandoned                           1
# pigging                             1
# pits                                1
# disposal facility                   1
# midstream                           1
# orphan                              1
# plugging                            1
# trucking                            1
# completion                          1
# transporation                       1
# Name: count, dtype: int64

# %%
# Column source - DONE
col_name = 'source'

typo_corrections = {
    'high prressure separator': 'high pressure separator',
    'hp separator': 'high pressure separator',
    '?': 'unknown',
    'pipline leak': 'pipeline leak', 
    'pl riser': 'pipeline riser', # a likely guess
    'pileline': 'pipeline'
}

target_labels = [
    'tank battery',
    'vacuum truck', 
    'flowline',
    'gathering line',
    'tank',
    'truck',
]

col_threshold = 90
new_col_name = col_name + '_clean'

# Cleaning process
data[new_col_name] = data[col_name].astype(str)
data[new_col_name] = impute_nulls(data[new_col_name]).apply(lambda x: x.lower())
data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))

# Check discrepancies
discrepancies = data[[col_name, new_col_name]]
discrepancies = discrepancies[discrepancies[col_name] != discrepancies[new_col_name]]
discrepancies.drop_duplicates()
# Out:
#                   source       source_clean
# 72                   NaN                nan
# 128           Frac Tanks         frac tanks
# 129         Tanker Truck       tanker truck
# 130                TANKS              tanks
# 203                 Tank               tank
# ...                  ...                ...
# 10220       HAMMER UNION       hammer union
# 10222  DUMP ON SEPARATOR  dump on separator
# 10228   Total Fluid Line   total fluid line
# 10231  Vehicle Collision  vehicle collision
# 10256    FIBERGLASS TANK    fiberglass tank
#
# [208 rows x 2 columns]

# %%
data['source_clean'].value_counts().head(15)
# Out:
# source_clean
# tank battery      4721
# flowline          2595
# well              1092
# other              398
# pipeline           286
# pump               271
# gathering line     269
# tank                65
# pit                 59
# heater treater      59
# nan                 59
# vehicle             41
# separator           27
# unknown             26
# plant               21
# Name: count, dtype: int64

# %%
# Column probable_cause_edit
col_name = 'probable_cause_edit'

typo_corrections = {}

new_col_name = col_name + '_clean'

# Cleaning process
data[new_col_name] = data[col_name].astype(str)
data[new_col_name] = impute_nulls(data[new_col_name]).apply(lambda x: x.lower())
data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))

# Check discrepancies
discrepancies = data[[col_name, new_col_name]]
discrepancies = discrepancies[discrepancies[col_name] != discrepancies[new_col_name]]
discrepancies.drop_duplicates()
# Out:
#         probable_cause_edit probable_cause_edit_clean
# 0                 CORROSION                 corrosion
# 2        MECHANICAL FAILURE        mechanical failure
# 11              HUMAN ERROR               human error
# 21                  WEATHER                   weather
# 128            Leaking tank              leaking tank
# ...                     ...                       ...
# 10205     FRAC INTERFERENCE         frac interference
# 10213  POSSIBLY FRAC'D INTO      possibly frac'd into
# 10215              FLOWLINE                  flowline
# 10216     FRACKING (NEARBY)         fracking (nearby)
# 10228          Leak in Line              leak in line
#
# [208 rows x 2 columns]

# %%
# Exploration for typos
#unique_vals = data[new_col_name].unique()
#plot_kcluster_elbow(unique_vals)
#show_kclusters(unique_vals, 10)

# %%
# Column comments
col_name = 'comments'

typo_corrections = {
}

new_col_name = col_name + '_clean'

# Cleaning process
data[new_col_name] = data[col_name].astype(str)
data[new_col_name] = impute_nulls(data[new_col_name]).apply(lambda x: x.lower())
data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))

# Check discrepancies
discrepancies = data[[col_name, new_col_name]]
discrepancies = discrepancies[discrepancies[col_name] != discrepancies[new_col_name]]
discrepancies.drop_duplicates()
# Out:
#                                                 comments  \
# 0                              Leak in gathering line DS
# 1                                                    NaN
# 2                                    Dump valve misfired
# 6      Spill inside metal containment area at tank ba...
# 8                     Flowline ruptured due to corrosion
# ...                                                  ...
# 10314                                    Broken flowline
# 10320                Injection line failed causing spill
# 10322                   Malfunction at tank caused spill
# 10324  Spill into North Fork Little Wichita River. Op...
# 10325                  12/10/21 RB - hole in tank bottom
#
#                                           comments_clean
# 0                              leak in gathering line ds
# 1                                                    nan
# 2                                    dump valve misfired
# 6      spill inside metal containment area at tank ba...
# 8                     flowline ruptured due to corrosion
# ...                                                  ...
# 10314                                    broken flowline
# 10320                injection line failed causing spill
# 10322                   malfunction at tank caused spill
# 10324  spill into north fork little wichita river. op...
# 10325                  12/10/21 rb - hole in tank bottom
#
# [3503 rows x 2 columns]

# %%
# Exploration for typos
#unique_vals = data[new_col_name].unique()
#plot_kcluster_elbow(unique_vals)
#show_kclusters(unique_vals, 10)

# %% [markdown]
# ## Clean loc_cols - 4/6

# %%
# EDA of the nullage
complete_log = [1, 0, 0, 1, 1, 1]
for col, complete in zip(loc_cols, complete_log): 
    print(col)
    print('sum of nulls:', data[col].isnull().sum())
    print('coverage:', ((len(data)-data[col].isnull().sum())/ len(data)) * 100)
    print('unique values:', data[col].nunique())
    if complete == 1: 
        print('!!! COMPLETE !!!')
    print()
# Out:
# district_edit
# sum of nulls: 0
# coverage: 100.0
# unique values: 13
# !!! COMPLETE !!!
#
# operator_edit
# sum of nulls: 1
# coverage: 99.99031570792175
# unique values: 1160
#
# lease_facility_name
# sum of nulls: 72
# coverage: 99.30273097036607
# unique values: 6651
#
# county_edit
# sum of nulls: 0
# coverage: 100.0
# unique values: 189
# !!! COMPLETE !!!
#
# affected_area
# sum of nulls: 83
# coverage: 99.19620375750533
# unique values: 50
# !!! COMPLETE !!!
#
# spill_on_water_edit
# sum of nulls: 765
# coverage: 92.59151656013945
# unique values: 12
# !!! COMPLETE !!!

# %%
# Column county_edit - DONE
col_name = 'county_edit'

typo_corrections = {
    'chldress': 'childress',
    'ecor': 'ector'
}

# Cleaning process
new_col_name = col_name + 'clean'
data[new_col_name] = impute_nulls(data[col_name]).apply(lambda x: x.lower())
data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))
data[new_col_name].value_counts()
# Out:
# county_editclean
# midland      658
# reeves       603
# martin       586
# andrews      529
# ector        509
#             ...
# mason          1
# coleman        1
# gillespie      1
# county         1
# mcculloch      1
# Name: count, Length: 187, dtype: int64

# %%
# DONE - new boolean columns
col_name = 'affected_area'

aa_categories = {
    # Are these RRC categories? Are these internal to operators?
    '1': '1= on land, non-sensitive area;',
    '2': '2= on land, sensitive area;', 
    '3': '3= dry waterway;',
    '4': '4= wet/flowing waterway;',
    '5': '5',
    '6': '6',
    '7': '7'
}

typo_corrections = {
    # Adding number labels, if possible
    '?': 'unknown',
    'land--non-sensitive area': '1 land--non-sensitive area',
    'land--sensitive area': '2 land--sensitive area',
    'wet/flowing waterway': '4 wet/flowing waterway', 
    'dry waterway': '3 dry waterway',
    'land --sensitive area': '2 land --sensitive area'
}

def create_boolean_columns(df, column_name, category_dict):
    # Iterate over the categories in the dictionary
    for key, value in category_dict.items():
        # Create a new column with the category name and initialize with False
        df[f'affected_area_{key}_clean'] = 0
        # Update the column based on the presence of the category in the specified column
        df.loc[df[column_name].str.contains(key), f'affected_area_{key}_clean'] = 1

# %%
# Manual checking process
data['affected_area'].value_counts()
# Out:
# affected_area
# 1                                 6002
# Land--Non-sensitive Area          2208
# 1= on land, non-sensitive area     559
# VERBAL                             365
# 2                                  297
# Verbal                             249
# 4                                  148
# Land--Sensitive Area                87
# 3                                   67
# EMAIL                               52
# Wet/Flowing Waterway                42
# 2=on land, sensitive area.          32
# Dry Waterway                        18
# Email                               16
# 2, 4                                12
# 2,4                                 12
# H-8                                 10
# verbal                               7
# 5                                    7
# Private Pond                         7
# 1, 4                                 4
# 3=dry  waterway                      4
# 1, 2                                 3
# 1, 3                                 3
# 4=Wet/flowing waterway               3
# 1,4                                  2
# 7                                    2
# 1, 2, 4                              2
# 1 & 2                                2
# In lined FW                          1
# 1, 3, 4                              1
# land--Non-sensitive Area             1
# Inland Bay Estuary                   1
# Land--Non-sensitive area             1
# No Call                              1
# 6                                    1
# 1, 2, 3                              1
# LANDOWNER                            1
# 1 (contianed in concrete TB)         1
# EMAL                                 1
# 4 (private pond-contained)           1
# 2, 3,4                               1
# 1,3                                  1
# 2, 3                                 1
# 1&4                                  1
# LETTER                               1
# Letter                               1
# 3, 2                                 1
# ?                                    1
# Land --Sensitive Area                1
# Name: count, dtype: int64

# %%
# Check for string values that contain numbers
vals_with_numbers = data[data['affected_area'].str.contains('\d', na=False)]['affected_area'].unique()
print(vals_with_numbers)
# Out:
# ['1' '1= on land, non-sensitive area' '3' '2' '4'
#  '2=on land, sensitive area.' '5' '7' '3, 2' 'H-8' '3=dry  waterway'
#  '4=Wet/flowing waterway' '1 & 2' '1&4' '1, 3' '2,4' '2, 3' '6' '1,3'
#  '1, 4' '1,4' '2, 4' '2, 3,4' '4 (private pond-contained)'
#  '1 (contianed in concrete TB)' '1, 2, 3' '1, 3, 4' '1, 2' '1, 2, 4']

# %%
# Cleaning process
new_col_name = col_name + '_clean'
data[new_col_name] = impute_nulls(data[col_name]).apply(lambda x: x.lower())

data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))

create_boolean_columns(data, new_col_name, aa_categories)
new_aa_columns = [i for i in data.columns.tolist() if 'affected_area' in i]

# %%
data[new_aa_columns].sample(15)
# Out:
#                        affected_area             affected_area_clean  \
# 5039                               1                               1
# 4918                               1                               1
# 631                                1                               1
# 8041        Land--Non-sensitive Area      1 land--non-sensitive area
# 4003                               1                               1
# 2421                               1                               1
# 4584  1= on land, non-sensitive area  1= on land, non-sensitive area
# 7681            Land--Sensitive Area          2 land--sensitive area
# 3791                               1                               1
# 2133                               1                               1
# 8710        Land--Non-sensitive Area      1 land--non-sensitive area
# 1926                               1                               1
# 1651                               1                               1
# 2160                               1                               1
# 1688      2=on land, sensitive area.      2=on land, sensitive area.
#
#       affected_area_1_clean  affected_area_2_clean  affected_area_3_clean  \
# 5039                      1                      0                      0
# 4918                      1                      0                      0
# 631                       1                      0                      0
# 8041                      1                      0                      0
# 4003                      1                      0                      0
# 2421                      1                      0                      0
# 4584                      1                      0                      0
# 7681                      0                      1                      0
# 3791                      1                      0                      0
# 2133                      1                      0                      0
# 8710                      1                      0                      0
# 1926                      1                      0                      0
# 1651                      1                      0                      0
# 2160                      1                      0                      0
# 1688                      0                      1                      0
#
#       affected_area_4_clean  affected_area_5_clean  affected_area_6_clean  \
# 5039                      0                      0                      0
# 4918                      0                      0                      0
# 631                       0                      0                      0
# 8041                      0                      0                      0
# 4003                      0                      0                      0
# 2421                      0                      0                      0
# 4584                      0                      0                      0
# 7681                      0                      0                      0
# 3791                      0                      0                      0
# 2133                      0                      0                      0
# 8710                      0                      0                      0
# 1926                      0                      0                      0
# 1651                      0                      0                      0
# 2160                      0                      0                      0
# 1688                      0                      0                      0
#
#       affected_area_7_clean
# 5039                      0
# 4918                      0
# 631                       0
# 8041                      0
# 4003                      0
# 2421                      0
# 4584                      0
# 7681                      0
# 3791                      0
# 2133                      0
# 8710                      0
# 1926                      0
# 1651                      0
# 2160                      0
# 1688                      0

# %%
# DONE
col_name = 'spill_on_water_edit'

typo_corrections = {
    '?': 'unknown',
    'undetermined': 'unknown'
}

target_labels = [
]

col_threshold = 90

# Cleaning process
new_col_name = col_name + '_clean'
data[new_col_name] = impute_nulls(data[col_name]).apply(lambda x: x.lower())
data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))
data[new_col_name].value_counts()
# Out:
# spill_on_water_edit_clean
# no                  9199
# null                 765
# yes                  351
# unknown                5
# 1                      2
# sulfide reducer        1
# paraffin               1
# rainwater              1
# isolated puddles       1
# Name: count, dtype: int64

# %%
data['operator_edit'].value_counts()
# Out:
# operator_edit
# Occidental Petroleum                                   997
# Pioneer Natural Resources (acq. by ExxonMobil 2023)    596
# XTO Energy (ExxonMobil subsidiary)                     589
# Endeavor Energy                                        393
# Energen (acq. by Diamondback 2019)                     310
#                                                       ...
# HUGOTON OPERATING COMPANY, INC                           1
# OILTON RESOURCES, INC                                    1
# M.E. OPERATING & SERVICES                                1
# FENOGLIO OIL COMPANY                                     1
# PINON OPERATING LLC                                      1
# Name: count, Length: 1160, dtype: int64

# %%
data['operator_edit'].value_counts().head(60)
# Out:
# operator_edit
# Occidental Petroleum                                   997
# Pioneer Natural Resources (acq. by ExxonMobil 2023)    596
# XTO Energy (ExxonMobil subsidiary)                     589
# Endeavor Energy                                        393
# Energen (acq. by Diamondback 2019)                     310
# Apache                                                 287
# Anadarko (acq. by Occidental 2019)                     235
# Parsley Energy                                         208
# Diamondback                                            179
# Denbury                                                178
# Linn Operating                                         171
# Chesapeake Energy                                      153
# Crownquest Operating                                   145
# EOG Resources                                          144
# Laredo Petroleum                                       142
# COG Operating                                          135
# Kinder Morgan                                          128
# Legacy Reserves Operating                              121
# WPX Energy                                             114
# Callon Petroleum                                       107
# Devon Energy                                           106
# Hilcorp Energy                                         103
# Enervest                                                93
# Cimarex Energy (merged into Coterra Energy 2021)        84
# Sheridan Production                                     83
# Marathon Oil                                            71
# Chevron                                                 65
# EP Energy                                               63
# Burlington Resources                                    62
# OVERFLOW ENERGY                                         57
# ConocoPhillips                                          56
# Encana Oil & Gas                                        55
# CHAPARRAL ENERGY                                        52
# CROSS TIMBERS                                           47
# East Texas Saltwater Disposal                           47
# DCP Midstream                                           46
# WALSH PETROLEUM                                         46
# JETTA OPERATING                                         45
# Sandridge Exploration & Production                      45
# DISCOVERY NATURAL RESOURCES                             40
# Targa                                                   36
# FDL OPERATING                                           36
# MEMORIAL PRODUCTION                                     36
# BTA OIL PRODUCERS                                       36
# SM ENERGY                                               35
# MERIT ENERGY COMPANY                                    34
# MURPHY EXPLORATION & PRODUCTION                         34
# BHP Billiton                                            33
# LE NORMAN OPERATING                                     32
# CITATION OIL & GAS CORP.                                32
# RESOLUTE NATURAL RESOURCES                              32
# RKI EXPLORATION & PRODUCTION                            31
# SURGE OPERATING                                         30
# HUNT OIL COMPANY                                        29
# SCOUT ENERGY                                            27
# Sabine Oil & Gas                                        27
# BASA RESOURCES                                          25
# ROSETTA RESOURCES OPERATING LP                          24
# JAGGED PEAK ENERGY                                      24
# Berry Oil                                               24
# Name: count, dtype: int64

# %%
# See how much collapse occurs when you lowercase things - nice
print(data['operator_edit'].nunique())
print(data['operator_edit'].str.lower().nunique())
# Out:
# 1160
# 1138

# %%
# What percentage of these strings only have a value count of 1?
value_counts = data['operator_edit'].value_counts()
duplicated_values = value_counts[value_counts == 1].index.tolist()
print(len(duplicated_values))

print(value_counts.describe())
# Out:
# 661
# count    1160.000000
# mean        8.900862
# std        45.697486
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         3.000000
# max       997.000000
# Name: count, dtype: float64

# %%
# DONE
col_name = 'lease_facility_name'

typo_corrections = {
    '?': 'unknown',
    'undetermined': 'unknown'
}

target_labels = [
]

col_threshold = 90

# Cleaning process
new_col_name = col_name + '_clean'
data[new_col_name] = impute_nulls(data[col_name]).apply(lambda x: x.lower())
data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))
data[new_col_name].value_counts()
# Out:
# lease_facility_name_clean
# fullerton clearfork unit    124
# sacroc unit                 107
# denver unit                  79
# means/san andres/unit        74
# null                         72
#                            ...
# o'daniel, e.t.                1
# bednorz 38                    1
# sale ranch 25c                1
# monroe 39 'a'                 1
# huey, sally                   1
# Name: count, Length: 6547, dtype: int64

# %%
data['lease_facility_name'].value_counts()
# Out:
# lease_facility_name
# Fullerton Clearfork Unit    124
# Sacroc Unit                 107
# Denver Unit                  79
# Means/San Andres/Unit        74
# Levelland Unit               65
#                            ...
# Powell "8"                    1
# Pecos Shearer Unit            1
# Tom A                         1
# Koger E 10                    1
# Huey, Sally                   1
# Name: count, Length: 6651, dtype: int64

# %%
# TODO
data['lease_facility_name'].sort_values().head(300).tolist()
# Out:
# ['00128 pipeline t4 permit.',
#  '10"  Pipeline - Kilgore City',
#  '10" Line Hopkins Facility',
#  '10" Line SND Burnside to McGeorge Tank',
#  '10" PVC Line @ 32.5011, -94.86428',
#  '115 SWD',
#  '16" BIGFOOT SOUR PIPELINE',
#  '1893 Oil & Gas Ltd.,',
#  '21601 Radio Tower State',
#  '281 SWD',
#  '281 SWD',
#  '281 SWD',
#  '283 SWD',
#  '3042 Heard Ranch AS PL',
#  '32.555789, -94.794136',
#  '508-32-Delmita Gathering System',
#  '6 Pounder SE',
#  '6" Deacon, Jim SDR 11',
#  '6" Gravity Line-Cates Ln',
#  '6" Grvity Line @ 32.4909, -94.9153',
#  '6" LINE',
#  '6" Polyline',
#  '6" Spence Gathering Line',
#  '6" TOTAL FLUIDS LINE',
#  '6" gravity line - Harris Lease',
#  '651 LTD. Benedum Univ.',
#  '7203 JV-S Amoco',
#  '7306 JV-S Wink',
#  '7502 JV-S R.O.C.',
#  '8 5/8" Gas Gather Line',
#  '8" Fiberglass transfer line',
#  '8" GATHERING LINE, Becker HG GU',
#  '8" Poly Line',
#  '8" Quantum/Castleberry SW line',
#  '8" Rosanky to Nixon Pipeline',
#  '8" SWPSI LINE FROM ANDERSON/ENGLAND',
#  '8" Transite Line',
#  '8" line on king lease',
#  '8-in Gathering Line',
#  '8.63" Crude Oil FWS, Scared Dog System',
#  '8207 JV-P Shannon',
#  '8333 SWD',
#  '8333 SWD',
#  '8333 SWD',
#  '8333 SWD',
#  '8333 SWD',
#  '8410 JV-P Mayfield',
#  '8410 JV-P Mayfield',
#  '8410 JV-P Mayfield',
#  '8410 JV-P Mayfield',
#  '8410 JV-p Watters',
#  '87 Airstrip SWD',
#  '87 Fairview SWD',
#  '8802 JV-P Fuhrman -F-',
#  '8802 JV-P Fuhrman -G-',
#  '9204 JV-P Whit',
#  '9217 JV-P Caprito',
#  '9217 JV-P Caprito',
#  '9217 JV-P Caprito',
#  '9217 JV-P Poquito',
#  '9217 JV-P Poquito',
#  '99 CDP',
#  '99 Plant',
#  '?',
#  'A Cope Oil Unit',
#  'A. Banduch A',
#  'A. WITTE A',
#  'A.F.T. Westcott SWD',
#  'ABNEY, R. K. # 2 tank battery',
#  'ACKERS, W.L.',
#  'ADAMS GU',
#  'ALEXANDER, CHARLES',
#  'ALEXANDER, JACOB GU 1 #1',
#  'ALLEE UNIT',
#  'ALLERKAMP, ERNEST E.',
#  'ALTITO A 23A UNIT',
#  'ALTITO B',
#  'ALTITO SOUTHEAST CPF',
#  'ALVIN NK UNIT',
#  'ANDERSON, ALMA GAS UNIT',
#  'ANDERSON, C. (CHEVRON)',
#  'ANDERSON-STONE DIM',
#  'ANGUS UNIT',
#  'ANTON URBANCZYK',
#  'APC 2-21',
#  'APC 28-10',
#  'APC 4 Inch Line',
#  'APC 54-1-18',
#  'APC 55-421',
#  'APC 76-10',
#  'APC 76-10',
#  'APC Fee 1-38 Unit',
#  'APC Fee 1-40',
#  'APC Fee 6',
#  'APC Gathering-SWD Facility',
#  'APC SWD',
#  'APC SWD',
#  'APC SWD',
#  'APC SWD',
#  'APC SWD',
#  'APC SWD',
#  'ARABIAN 1H (CMGL 01-5944)',
#  'ARNOLD CPF',
#  'ASHLEY ANN',
#  'ASRO 13 Unit',
#  'ATASCOSA SWD',
#  'AVANT, J.R.',
#  'AVERILL, TERRELL ETTA',
#  'AVERILL, TERRELL ETTA',
#  'Abbie Laine',
#  'Abbott Estate',
#  'Abel',
#  'Abel',
#  'Abel',
#  'Abel',
#  'Abernathy 2',
#  'Abernathy 20',
#  'Abernathy 20',
#  'Abernathy 20',
#  'Abernathy 20',
#  'Abernathy 20',
#  'Abernathy 20',
#  'Abernathy 20',
#  'Abigail',
#  'Abraham Compressor Station',
#  'Abraham SW',
#  'Abrams, W.H.',
#  'Abrams, W.H. (04505)',
#  'Acirema Corporation, F. C. Christian',
#  'Ackerly/Dean/Field Unit',
#  'Ackerly/Dean/Field Unit',
#  'Ackerly/Dean/Field Unit',
#  'Ackerly/Dean/Field Unit',
#  'Ackerly/Dean/Field Unit',
#  'Ackerly/Dean/Field Unit',
#  'Ackerly/Dean/Field Unit',
#  'Ackerly/Dean/Field Unit',
#  'Ackerly/Dean/Field Unit',
#  'Ackerly/Dean/Field Unit',
#  'Ackerly/Dean/Field Unit',
#  'Ackers, L.J.',
#  'Ackers, L.J.',
#  'Acola, Sam "A"',
#  'Act G',
#  'Adair San Andres Unit',
#  'Adair San Andres Unit',
#  'Adair San Andres Unit',
#  'Adam',
#  'Adamc/Devonian/Unit',
#  'Adams "A" #11',
#  'Adams 26',
#  'Adams 38',
#  'Adams 43-6 E',
#  'Adams H',
#  'Adams Legacy',
#  'Adams Legacy',
#  'Adams Legacy',
#  'Adams NS 43-6 01',
#  'Adams Ranch B',
#  'Adams West 29',
#  'Adams, "E"',
#  'Adams, G. Unit',
#  'Adams, H.E.',
#  'Addis, Frank V. -D-',
#  'Adkins',
#  'Adobe',
#  'Adobe',
#  'Adobe',
#  'Adobe',
#  'Adolph',
#  'Aermotor 27',
#  'Agate 179SE',
#  'Agnes 80',
#  'Agurs, W.C.',
#  'Airhart "7"',
#  'Akin, JW',
#  'Alameda',
#  'Alamo',
#  'Albright, Oliver J.',
#  'Alcatraz State 34-141 Unit',
#  'Alderman Ranch North Facility',
#  'Aldwell M R40',
#  'Aledo Yard',
#  'Aledo Yard',
#  'Aledo Yard',
#  'Alexander',
#  'Alexander',
#  'Alexander',
#  'Alexander - Bivins Pressure Line',
#  'Alexander 33',
#  'Alexander 58-T2-12',
#  'Alexander 67',
#  'Alexander Bird 43-6',
#  'Alexander Heirs Gas Unit',
#  'Alexander Heirs Gas Unit',
#  'Alexander Ranch',
#  'Alexander Ranch',
#  'Alexander Ranch',
#  'Alexander Unit',
#  'Alexander Unit 66',
#  'Alexander, Birdie R.',
#  'Alexander, Birdie R.',
#  'Alexander, Birdie R.',
#  'Alexander, Charles',
#  'Alexander, Charles',
#  'Alexandra 11H',
#  'Alison',
#  'Allar 15',
#  'Allar 19',
#  'Allar 25',
#  'Allar 25',
#  'Allar 3',
#  'Allar 7',
#  'Allen, J. E. -A-',
#  'Allen, R. S.',
#  'Alley',
#  'Alley "A"',
#  'Alley "A"',
#  'Alliance Airport KS Unit',
#  'Allison',
#  'Allison 36-54 Alloc A',
#  'Allison 4',
#  'Allman 25 SWD',
#  'Allred Unit A 08-05',
#  'Allred Unit B 08-05',
#  'Altas 1 SWD Inlet Pipeline',
#  'Altito A',
#  'Altito A 23A Unit',
#  'Altito D Unit',
#  'Altman, Ben',
#  'Alyx State 22',
#  'Amacker-Tippett "A" Pool Unit',
#  'Amado Perez',
#  'Amanda B',
#  'Amerada-Webb',
#  'Amerada-Webb',
#  'Amerada-Webb',
#  'Amerada-Webb',
#  'Amerada-Webb',
#  'American Farroh 1-2H CTB',
#  'American Pharoah 43 State Unit',
#  'Amerigo 901A',
#  'Ammit Unit 23-14',
#  'Amoco Fee "B"',
#  "Amoco-Blanche 'A' 2-28",
#  'Amoco-Collier Estate',
#  'Amphitheater A1',
#  'Anaconda 53-24',
#  'Anadarko SCO 1-04 8"',
#  'Anadarko System Pipeline',
#  'Anderson "16A"',
#  'Anderson "B"',
#  'Anderson -A-',
#  'Anderson 11',
#  'Anderson 15',
#  'Anderson 2',
#  'Anderson 32',
#  'Anderson 8" SW Line',
#  'Anderson Center',
#  'Anderson Pit',
#  'Anderson Ranch 61',
#  'Anderson Unit',
#  'Anderson, C.H.C.',
#  'Anderson-Cooper S-2 Unit',
#  'Anderson-Stone DIM',
#  'Andrews Unit',
#  'Andrews Unit',
#  'Andrews Unit',
#  'Angelina SN 33-28 07',
#  'Angie',
#  'Anguish',
#  'Ani SWD',
#  'Animal Kingdom 44 Unit',
#  'Ann29',
#  'Anna Marie SWD',
#  'Anna Marie SWD',
#  'AnnaKatherine 23',
#  'Anne 24   #1H',
#  'Annie',
#  'Annie',
#  'Annie',
#  'Anselin-Babcock',
#  'Anselin-Babcock',
#  'Antelope Hills Gas Plant',
#  'Anthony Forest Products',
#  'Anthony West Unit',
#  'Antimony FR 30',
#  'Anton Irish Clearfork Unit',
#  'Anton-Irish Clearfork',
#  'Anton-Irish Clearfork Unit',
#  'Anton-Irish Clearfork Unit',
#  'Anton-Irish Clearfork Unit',
#  'Anton-Irish Clearfork Unit',
#  'Anton-Irish Clearfork Unit',
#  'Anton-Irish Clearfork Unit',
#  'Anton-Irish Clearfork Unit',
#  'Anton-Irish Clearfork Unit',
#  'Anton-Irish Clearfork Unit',
#  'Anton-Irish Clearfork Unit',
#  'Anton-Irish Clearfork Unit']

# %% [markdown]
# ## Cleaning Rep Cols

# %%
rep_cols = [
'date_called_in_edit',
'date_of_spill_edit',
'spill_number', 
'rrc_job_number',
'basis', 
'affected_area', 
'swr_20', 
'swr_98exempt',
'cleanup_criteria', 
'cleanup_criteria_swr_91', 
'cleanup_criteria_7_00_doc', 
'cleanup_criteria_case_specific', 
'form_h_8rqrd_edit',
'date_h_8rcvd', 
'cleanup_oversight', 
'cleanup_oversight_district', 
'cleanup_oversight_austin', 
'status', 
'compliance_date'
]
print(len(rep_cols))
# Out:
# 19

# %%
complete_log = np.zeros(19)
for col, complete in zip(rep_cols, complete_log): 
    print(col)
    print('sum of nulls:', data[col].isnull().sum())
    print('coverage:', ((len(data)-data[col].isnull().sum())/ len(data)) * 100)
    print('unique values:', data[col].nunique())
    print(data[col].value_counts())
    if complete == 1: 
        print('!!! COMPLETE !!!')
    print()
    print()
# Out:
# date_called_in_edit
# sum of nulls: 24
# coverage: 99.76757699012202
# unique values: 2948
# date_called_in_edit
# 2015-10-21    22
# 2022-12-27    21
# 2015-01-05    19
# 2016-07-11    18
# 2021-02-23    18
#               ..
# 2019-02-07     1
# 2019-02-05     1
# 2019-03-24     1
# 2019-03-19     1
# 2021-02-03     1
# Name: count, Length: 2948, dtype: int64
#
#
# date_of_spill_edit
# sum of nulls: 0
# coverage: 100.0
# unique values: 3287
# date_of_spill_edit
# 2015-05-19    16
# 2015-10-20    16
# 2017-08-27    14
# 2015-01-06    14
# 2015-01-15    14
#               ..
# 2020-12-04     1
# 2020-12-08     1
# 2020-12-31     1
# 2021-12-25     1
# 2021-02-03     1
# Name: count, Length: 3287, dtype: int64
#
#
# spill_number
# sum of nulls: 2876
# coverage: 72.14797598295564
# unique values: 6821
# spill_number
# -           25
# 9            8
# 5            8
# 37           7
# 29           7
#             ..
# 08-13582     1
# 08-13580     1
# 08-13578     1
# 08-13569     1
# 8A-14592     1
# Name: count, Length: 6821, dtype: int64
#
#
# rrc_job_number
# sum of nulls: 24
# coverage: 99.76757699012202
# unique values: 10239
# rrc_job_number
# 14-5865    2
# 14-1337    2
# 5489       2
# 219817     2
# 220677     2
#           ..
# 16835      1
# 16611      1
# 15068      1
# 17607      1
# 281395     1
# Name: count, Length: 10239, dtype: int64
#
#
# basis
# sum of nulls: 2070
# coverage: 79.9535153980244
# unique values: 23
# basis
# Other Rpt        4309
# Operator         1636
# H-8              1283
# 0                 668
# Verbal            157
# VERBAL             77
# operator           44
# Email              33
# other              13
# other rpt           9
# EMAIL               6
# Letter              4
# other report        4
# ?                   2
# other Rpt           2
# verbal              2
# 80                  1
# LETTER              1
# SMCU                1
# Other               1
# SWR 20 Letter       1
# Rule 20             1
# opreator            1
# Name: count, dtype: int64
#
#
# affected_area
# sum of nulls: 83
# coverage: 99.19620375750533
# unique values: 50
# affected_area
# 1                                 6002
# Land--Non-sensitive Area          2208
# 1= on land, non-sensitive area     559
# VERBAL                             365
# 2                                  297
# Verbal                             249
# 4                                  148
# Land--Sensitive Area                87
# 3                                   67
# EMAIL                               52
# Wet/Flowing Waterway                42
# 2=on land, sensitive area.          32
# Dry Waterway                        18
# Email                               16
# 2, 4                                12
# 2,4                                 12
# H-8                                 10
# verbal                               7
# 5                                    7
# Private Pond                         7
# 1, 4                                 4
# 3=dry  waterway                      4
# 1, 2                                 3
# 1, 3                                 3
# 4=Wet/flowing waterway               3
# 1,4                                  2
# 7                                    2
# 1, 2, 4                              2
# 1 & 2                                2
# In lined FW                          1
# 1, 3, 4                              1
# land--Non-sensitive Area             1
# Inland Bay Estuary                   1
# Land--Non-sensitive area             1
# No Call                              1
# 6                                    1
# 1, 2, 3                              1
# LANDOWNER                            1
# 1 (contianed in concrete TB)         1
# EMAL                                 1
# 4 (private pond-contained)           1
# 2, 3,4                               1
# 1,3                                  1
# 2, 3                                 1
# 1&4                                  1
# LETTER                               1
# Letter                               1
# 3, 2                                 1
# ?                                    1
# Land --Sensitive Area                1
# Name: count, dtype: int64
#
#
# swr_20
# sum of nulls: 426
# coverage: 95.87449157466588
# unique values: 9
# swr_20
# yes                   4373
# Yes                   2249
# no                    2191
# 0                      708
# No                     247
# YES                    106
# NO                      23
# NR                       2
# yes (not received)       1
# Name: count, dtype: int64
#
#
# swr_98exempt
# sum of nulls: 359
# coverage: 96.52333914390859
# unique values: 8
# swr_98exempt
# no               6557
# No               2470
# 0                 709
# yes               100
# NO                 83
# Yes                40
# YES                 7
# no (lined FW)       1
# Name: count, dtype: int64
#
#
# cleanup_criteria
# sum of nulls: 8075
# coverage: 21.799341468138678
# unique values: 11
# cleanup_criteria
# SWR 91                 1620
# Case Specific           589
# Condensate Guidance      27
# SWR91                     4
# no                        3
# Yes                       2
# sWR 91                    2
# No                        1
# SWR 92                    1
# SWR 93                    1
# case specific             1
# Name: count, dtype: int64
#
#
# cleanup_criteria_swr_91
# sum of nulls: 3753
# coverage: 63.654851830331204
# unique values: 12
# cleanup_criteria_swr_91
# yes    2872
# no     2719
# Yes     551
# X       145
# No      141
# YES      85
# NO       41
# 0        15
# x         1
# 133       1
# 120       1
# 107       1
# Name: count, dtype: int64
#
#
# cleanup_criteria_7_00_doc
# sum of nulls: 6506
# coverage: 36.99399573891149
# unique values: 44
# cleanup_criteria_7_00_doc
# no                                           2233
# 1                                             630
# yes                                           125
# Hal                                           113
# Bobby                                         102
# NO                                             83
# Lonny                                          79
# No                                             72
# X                                              56
# Kevin                                          53
# Abe                                            48
# 2                                              35
# Steven                                         31
# Billy                                          21
# Bruce                                          19
# Jerry                                          19
# Justin                                         17
# Jesse                                          15
# Yes                                            14
# 0                                               6
# Andrea                                          6
# 3                                               4
# Katy                                            4
# Dennis                                          4
# Billy K                                         3
# sensitive area                                  3
# condensate                                      2
# YES                                             2
# Ronnie                                          2
# Gerry                                           2
# HAL                                             2
# David                                           2
# x                                               2
# Justin/Troyce                                   1
# Dist 8                                          1
# SMCU Cleanup                                    1
# 4                                               1
# Jerrry                                          1
# BOBBY                                           1
# SW in a pond w/~5,000ppm Chlorides at POE       1
# Leslie                                          1
# Creek                                           1
# condensate spill                                1
# JERRY                                           1
# Name: count, dtype: int64
#
#
# cleanup_criteria_case_specific
# sum of nulls: 6060
# coverage: 41.313190005810576
# unique values: 452
# cleanup_criteria_case_specific
# yes      1901
# no        543
# NO        454
# No        264
# X         239
#          ...
# 42627       1
# 42621       1
# 42620       1
# 42619       1
# 42530       1
# Name: count, Length: 452, dtype: int64
#
#
# form_h_8rqrd_edit
# sum of nulls: 236
# coverage: 97.71450706953321
# unique values: 28
# form_h_8rqrd_edit
# YES                            5490
# no                             2668
# No                             1407
# NO                              495
# ?                                 6
# 41708                             2
# -                                 1
# n                                 1
# 42489                             1
# 42395                             1
# 42261                             1
# 42146                             1
# 42145                             1
# 42109                             1
# 42095                             1
# 42083                             1
# 41922                             1
# H-8 recvd in lieu of letter       1
# 41901                             1
# 41907                             1
# 41848                             1
# 41845                             1
# 41652                             1
# 41590                             1
# nO                                1
# 41578                             1
# 41543                             1
# N                                 1
# Name: count, dtype: int64
#
#
# date_h_8rcvd
# sum of nulls: 7100
# coverage: 31.241526244431533
# unique values: 1393
# date_h_8rcvd
# YES             360
# Yes             252
# Not Required    146
# NO               85
# yes              67
#                ...
# 2017-05-26        1
# 6/13/2017^        1
# 2017-07-21        1
# 7/6/2017^         1
# 2000-10-01        1
# Name: count, Length: 1393, dtype: int64
#
#
# cleanup_oversight
# sum of nulls: 7977
# coverage: 22.748402091807087
# unique values: 1
# cleanup_oversight
# District    2349
# Name: count, dtype: int64
#
#
# cleanup_oversight_district
# sum of nulls: 309
# coverage: 97.00755374782104
# unique values: 306
# cleanup_oversight_district
# EH       824
# LSS      726
# MC       684
# JDM      668
# JM       618
#         ...
# 42843      1
# 42850      1
# 42851      1
# 42934      1
# 42997      1
# Name: count, Length: 306, dtype: int64
#
#
# cleanup_oversight_austin
# sum of nulls: 8729
# coverage: 15.46581444896378
# unique values: 122
# cleanup_oversight_austin
# No           571
# YES          324
# Yes          240
# NO            91
# MWS           36
#             ...
# SS/GP          1
# AJC (MB)       1
# BCR (TNB)      1
# MWs            1
# 43005          1
# Name: count, Length: 122, dtype: int64
#
#
# status
# sum of nulls: 441
# coverage: 95.72922719349216
# unique values: 67
# status
# cleanup phase                                                     5795
# In Process                                                        1814
# assessment phase                                                   494
# Completed                                                          465
# closed                                                             426
#                                                                   ...
# Transfer hose from open top tank for frac tank had a hole            1
# Will excavated, sample, analyze for BTEX & Chlorides, backfill       1
# GP/RR                                                                1
# GP/?                                                                 1
# SS                                                                   1
# Name: count, Length: 67, dtype: int64
#
#
# compliance_date
# sum of nulls: 8468
# coverage: 17.993414681386792
# unique values: 759
# compliance_date
# YES                     363
# Yes                     241
# reported by operator     58
# NO                       57
# CLEAN-UP                 50
#                        ...
# 2019-10-24                1
# 2014-03-06                1
# .                         1
# 2019-11-21                1
# 947                       1
# Name: count, Length: 759, dtype: int64

# %%
# Column 
col_name = 'basis'

typo_corrections = {
    'opreator': 'operator'

}
new_col_name = col_name + '_clean'

# Cleaning process
data[new_col_name] = data[col_name].astype(str)
data[new_col_name] = impute_nulls(data[new_col_name]).apply(lambda x: x.lower())
data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))

# Check discrepancies
discrepancies = data[[col_name, new_col_name]]
discrepancies = discrepancies[discrepancies[col_name] != discrepancies[new_col_name]]
discrepancies.drop_duplicates()
# Out:
#               basis    basis_clean
# 0         Other Rpt      other rpt
# 1               NaN            nan
# 11              H-8            h-8
# 128          Verbal         verbal
# 205          Letter         letter
# 341         Rule 20        rule 20
# 612   SWR 20 Letter  swr 20 letter
# 1004      other Rpt      other rpt
# 3806         VERBAL         verbal
# 3810          EMAIL          email
# 4062         LETTER         letter
# 4752           SMCU           smcu
# 6044          Other          other
# 7305       Operator       operator
# 7541          Email          email
# 9704       opreator       operator

# %%
data[new_col_name].value_counts()
# Out:
# basis_clean
# other rpt        4320
# nan              2070
# operator         1681
# h-8              1283
# 0                 668
# verbal            236
# email              39
# other              14
# letter              5
# other report        4
# ?                   2
# rule 20             1
# swr 20 letter       1
# 80                  1
# smcu                1
# Name: count, dtype: int64

# %%
# Column 
col_name = 'swr_20'

typo_corrections = {
    'opreator': 'operator'
}

new_col_name = col_name + '_clean'

# Cleaning process
data[new_col_name] = data[col_name].astype(str)
data[new_col_name] = impute_nulls(data[new_col_name]).apply(lambda x: x.lower())
data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))

# Check discrepancies
discrepancies = data[[col_name, new_col_name]]
discrepancies = discrepancies[discrepancies[col_name] != discrepancies[new_col_name]]
discrepancies.drop_duplicates()
# Out:
#      swr_20 swr_20_clean
# 1       NaN          nan
# 128     Yes          yes
# 1470     No           no
# 3806     NO           no
# 3807    YES          yes
# 6793     NR           nr

# %%
data[new_col_name].value_counts()
# Out:
# swr_20_clean
# yes                   6728
# no                    2461
# 0                      708
# nan                    426
# nr                       2
# yes (not received)       1
# Name: count, dtype: int64

# %%
# Column 
col_name = 'swr_98exempt'

typo_corrections = {
}

new_col_name = col_name + '_clean'

# Cleaning process
data[new_col_name] = data[col_name].astype(str)
data[new_col_name] = impute_nulls(data[new_col_name]).apply(lambda x: x.lower())
data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))

# Check discrepancies
discrepancies = data[[col_name, new_col_name]]
discrepancies = discrepancies[discrepancies[col_name] != discrepancies[new_col_name]]
discrepancies.drop_duplicates()
# Out:
#        swr_98exempt swr_98exempt_clean
# 1               NaN                nan
# 128              No                 no
# 3155            YES                yes
# 3806             NO                 no
# 4075  no (lined FW)      no (lined fw)
# 5978            Yes                yes

# %%
data[new_col_name].value_counts()
# Out:
# swr_98exempt_clean
# no               9110
# 0                 709
# nan               359
# yes               147
# no (lined fw)       1
# Name: count, dtype: int64

# %%
# Column 
col_name = 'cleanup_criteria'

typo_corrections = {
    'swr91': 'swr 91',

}

new_col_name = col_name + '_clean'

# Cleaning process
data[new_col_name] = data[col_name].astype(str)
data[new_col_name] = impute_nulls(data[new_col_name]).apply(lambda x: x.lower())
data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))

# Check discrepancies
discrepancies = data[[col_name, new_col_name]]
discrepancies = discrepancies[discrepancies[col_name] != discrepancies[new_col_name]]
discrepancies.drop_duplicates()
# Out:
#          cleanup_criteria cleanup_criteria_clean
# 0                     NaN                    nan
# 7294               SWR 91                 swr 91
# 7295        Case Specific          case specific
# 7600                   No                     no
# 7601                  Yes                    yes
# 7613  Condensate Guidance    condensate guidance
# 8063               SWR 92                 swr 92
# 8064               SWR 93                 swr 93
# 8373                SWR91                 swr 91
# 8722               sWR 91                 swr 91

# %%
data[new_col_name].value_counts()
# Out:
# cleanup_criteria_clean
# nan                    8075
# swr 91                 1626
# case specific           590
# condensate guidance      27
# no                        4
# yes                       2
# swr 92                    1
# swr 93                    1
# Name: count, dtype: int64

# %%
# Column 
col_name = 'cleanup_criteria_swr_91'

typo_corrections = {
    'swr91': 'swr 91',

}
new_col_name = col_name + '_clean'

# Cleaning process
data[new_col_name] = data[col_name].astype(str)
data[new_col_name] = impute_nulls(data[new_col_name]).apply(lambda x: x.lower())
data[new_col_name] = data[new_col_name].apply(lambda x: correct_typos(x, typo_corrections))

# Check discrepancies
discrepancies = data[[col_name, new_col_name]]
discrepancies = discrepancies[discrepancies[col_name] != discrepancies[new_col_name]]
discrepancies.drop_duplicates()
# Out:
#      cleanup_criteria_swr_91 cleanup_criteria_swr_91_clean
# 1                        NaN                           nan
# 2                        Yes                           yes
# 72                        No                            no
# 217                      YES                           yes
# 764                        X                             x
# 3809                      NO                            no

# %%
data[new_col_name].value_counts()
# Out:
# cleanup_criteria_swr_91_clean
# nan    3753
# yes    3508
# no     2901
# x       146
# 0        15
# 133       1
# 120       1
# 107       1
# Name: count, dtype: int64

# %%
data.to_csv('./clean_data/' + 'clean_central_data.csv')
